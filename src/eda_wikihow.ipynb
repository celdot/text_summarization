# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import re
import numpy as np
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
import utils.preprocessing as pre
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\celin_e3kjw6h\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wikihow_dir = os.path.join(Path.cwd().parent, "raw_data", "WikiHow")
dataset_dir = os.path.join(Path.cwd().parent, "data")
figures_dir = os.path.join(Path.cwd().parent, "figures")
os.makedirs(dataset_dir, exist_ok=True)
os.makedirs(figures_dir, exist_ok=True)

# %% [markdown]
# ## Get the data

# %%
wikihow_df = pd.read_csv(os.path.join(wikihow_dir, "wikihowSep.csv"))

# %% [markdown]
# ## Preprocess the data

# %%
wikihow_df = pre.preprocessing_pipeline(wikihow_df, stopwords, dataset_dir, "wikihow_data", start_token = "<s> ", end_token = " </s>")
# Out:
# d:\KTH\DD2434 Language Engineering\text_summarization\src\utils\preprocessing.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = start_token + df[column_name] + end_token
# d:\KTH\DD2434 Language Engineering\text_summarization\src\utils\preprocessing.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'length_{column_name}'] = df[column_name].apply(lambda x: len(x.split()))
# ...

# %%
wikihow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251774 entries, 0 to 1585694
# Data columns (total 4 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   summary         1251774 non-null  object
#  1   text            1251774 non-null  object
#  2   length_summary  1251774 non-null  int64
#  3   length_text     1251774 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 47.8+ MB

# %% [markdown]
# ## Get distribution of the data

# %%
pre.get_data_distribution(wikihow_df, figures_dir, "wikihow")
